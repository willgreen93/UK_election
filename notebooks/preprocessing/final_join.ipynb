# %%
import pandas as pd

# %%
# Import census data
census_df = pd.read_csv('/Users/andreabrumana/code/willgreen93/UK_election/raw_data/preprocessed/preprocessed_interpolated_census_data.csv')
census_df.head()
# Out:
#   constituency_name constituency_id  year     0-9   10-19   20-29   30-39  \
# 0          Aberavon       W07000049  2010  0.1068  0.1242  0.1227  0.1246
# 1          Aberavon       W07000049  2011  0.1082  0.1203  0.1227  0.1256
# 2          Aberavon       W07000049  2012  0.1096  0.1164  0.1227  0.1266
# 3          Aberavon       W07000049  2013  0.1110  0.1125  0.1227  0.1276
# 4          Aberavon       W07000049  2014  0.1121  0.1105  0.1242  0.1273
#
#     40-49   50-59   60-69   70-79     80+  Home_owners  Private_renters  \
# 0  0.1446  0.1311  0.1149  0.0778  0.0528     0.686902         0.109669
# 1  0.1413  0.1334  0.1168  0.0786  0.0528     0.683026         0.113468
# 2  0.1380  0.1357  0.1187  0.0794  0.0528     0.679151         0.117268
# 3  0.1347  0.1380  0.1206  0.0802  0.0528     0.675276         0.121067
# 4  0.1310  0.1403  0.1210  0.0809  0.0528     0.671401         0.124867
#
#    Social_renters     Asian     Black     Mixed     Other     White
# ...

# %%
# Import eelction/pollig data
election_polling_df = pd.read_csv('/Users/andreabrumana/code/willgreen93/UK_election/raw_data/preprocessed/preprocessed_election_polling.csv')
election_polling_df.info()
election_polling_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3237 entries, 0 to 3236
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   year               3237 non-null   int64
#  1   constituency_id    3237 non-null   object
#  2   constituency_name  3237 non-null   object
#  3   country/region     3237 non-null   object
#  4   total_votes        2587 non-null   float64
#  5   con_votes          2587 non-null   float64
#  6   lab_votes          2587 non-null   float64
#  7   lib_votes          2587 non-null   float64
#  8   oth_votes          2587 non-null   float64
#  9   con_share          2587 non-null   float64
#  10  lab_share          2587 non-null   float64
#  11  lib_share          2587 non-null   float64
#  12  oth_share          2587 non-null   float64
#  13  con_share_prev     3237 non-null   float64
#  14  lab_share_prev     3237 non-null   float64
# ...

# %%
# Merge the dfs
final_df = pd.merge(census_df, election_polling_df, on=['constituency_id', 'year'], how='inner')
final_df.rename(columns={'constituency_name_x': 'constituency_name'}, inplace=True)
final_df.drop(columns=['constituency_name_y'], inplace=True)

# %%
final_df.year.unique()
# Out:
# array([2010, 2015, 2017, 2019, 2024])

# %%
final_df.to_csv('/Users/andreabrumana/code/willgreen93/UK_election/raw_data/preprocessed/preprocessed_final_df.csv', index=False)
