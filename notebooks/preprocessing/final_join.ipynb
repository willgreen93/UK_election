# %%
import pandas as pd

# %%
# Import census data
census_df = pd.read_csv('/Users/andreabrumana/code/willgreen93/UK_election/raw_data/preprocessed/preprocessed_interpolated_census_data.csv')
census_df.head()
# Out:
#   constituency_name constituency_id  year     0-9   10-19   20-29   30-39  \
# 0          Aberavon       W07000049  2010  0.1068  0.1242  0.1227  0.1246
# 1          Aberavon       W07000049  2011  0.1082  0.1203  0.1227  0.1256
# 2          Aberavon       W07000049  2012  0.1096  0.1164  0.1227  0.1266
# 3          Aberavon       W07000049  2013  0.1110  0.1125  0.1227  0.1276
# 4          Aberavon       W07000049  2014  0.1121  0.1105  0.1242  0.1273
#
#     40-49   50-59   60-69   70-79     80+  Home_owners  Private_renters  \
# 0  0.1446  0.1311  0.1149  0.0778  0.0528     0.686902         0.109669
# 1  0.1413  0.1334  0.1168  0.0786  0.0528     0.683026         0.113468
# 2  0.1380  0.1357  0.1187  0.0794  0.0528     0.679151         0.117268
# 3  0.1347  0.1380  0.1206  0.0802  0.0528     0.675276         0.121067
# 4  0.1310  0.1403  0.1210  0.0809  0.0528     0.671401         0.124867
#
#    Social_renters     Asian     Black     Mixed     Other     White
# ...

# %%
# Import eelction/pollig data
election_polling_df = pd.read_csv('/Users/andreabrumana/code/willgreen93/UK_election/raw_data/preprocessed/election_polling_joined.csv')
election_polling_df.head()
# Out:
#    year constituency_id constituency_name country/region  total_votes  \
# 0  2010       W07000049          Aberavon          Wales        30958
# 1  2010       W07000058         Aberconwy          Wales        29966
# 2  2010       S14000001    Aberdeen North       Scotland        37701
# 3  2010       S14000002    Aberdeen South       Scotland        43034
# 4  2010       S14000003  Airdrie & Shotts       Scotland        35849
#
#    con_votes  lab_votes  lib_votes  oth_votes  con_share  ...  \
# 0     4411.0    16073.0     5034.0     5440.0      0.142  ...
# 1    10734.0     7336.0     5786.0     6110.0      0.358  ...
# 2     4666.0    16746.0     7001.0     9288.0      0.124  ...
# 3     8914.0    15722.0    12216.0     6182.0      0.207  ...
# 4     3133.0    20849.0     2898.0     8969.0      0.087  ...
#
#    national_lib_pre_ge  national_oth_pre_ge  mean_con_share_pre_ge  \
# 0                 0.27                0.091               0.307918
# ...

# %%
# Merge the dfs
final_df = pd.merge(census_df, election_polling_df, on=['constituency_id', 'year'])
final_df.rename(columns={'constituency_name_x': 'constituency_name'}, inplace=True)
final_df.drop(columns=['constituency_name_y'], inplace=True)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2279 entries, 0 to 2278
# Data columns (total 46 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   constituency_name      2279 non-null   object
#  1   constituency_id        2279 non-null   object
#  2   year                   2279 non-null   int64
#  3   0-9                    2279 non-null   float64
#  4   10-19                  2279 non-null   float64
#  5   20-29                  2279 non-null   float64
#  6   30-39                  2279 non-null   float64
#  7   40-49                  2279 non-null   float64
#  8   50-59                  2279 non-null   float64
#  9   60-69                  2279 non-null   float64
#  10  70-79                  2279 non-null   float64
#  11  80+                    2279 non-null   float64
#  12  Home_owners            2279 non-null   float64
#  13  Private_renters        2279 non-null   float64
# ...
