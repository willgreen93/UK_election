# %% [markdown]
# This notebook is used to calculate the incumbent party for each constituency in each election year.
# <br />
# The incumbent party is the party that won the previous election in that constituency.
# <br />
#
# ### **PLEASE NOTE!**
# For 2010 we need to get 2005 data, with the complications that in 2005 we do not have a correct ID, so we need to use the name
# From 2015 onwards, we can use the ID of the consitutency

# %%
import pandas as pd
from google.cloud import storage

# %%
data = pd.read_csv('/Users/andreabrumana/code/willgreen93/UK_election/raw_data/cleaned_election_results.csv')
data.head()
# Out:
#    year constituency_id             constituency  country  electorate  \
# 0  2001               1                  BEDFORD  England       67762
# 1  2001               2              LUTON NORTH  England       67554
# 2  2001               3              LUTON SOUTH  England       71439
# 3  2001               4         MID BEDFORDSHIRE  England       70794
# 4  2001               5  NORTH EAST BEDFORDSHIRE  England       69877
#
#    total_votes   tornout  conservative_votes  conservative_vote_share  \
# 0        40579  0.598846             13297.0                 0.327682
# 1        39126  0.579181             12210.0                 0.312069
# 2        39351  0.550834             11586.0                 0.294427
# 3        46638  0.658785             22109.0                 0.474055
# 4        45246  0.647509             22586.0                 0.499182
#
#    labour_votes  labour_vote_share  liberal_democrats_votes  \
# 0       19454.0           0.479411                   6425.0
# 1       22187.0           0.567065                   3795.0
# 2       21719.0           0.551930                   4292.0
# 3       14043.0           0.301106                   9205.0
# 4       14009.0           0.309619                   7409.0
#
#    liberal_democrats_vote_share  main_parties_votes  main_parties_vote_share  \
# 0                      0.158333             39176.0                 0.965425
# 1                      0.096994             38192.0                 0.976128
# 2                      0.109070             37597.0                 0.955427
# 3                      0.197371             45357.0                 0.972533
# 4                      0.163749             44004.0                 0.972550
#
#    other_parties_votes  other_parties_vote_share
# 0               1403.0                  0.034575
# 1                934.0                  0.023872
# 2               1754.0                  0.044573
# 3               1281.0                  0.027467
# 4               1242.0                  0.027450

# %%
data['winning_party'] = data[['conservative_vote_share', 'labour_vote_share', 'liberal_democrats_vote_share', 'other_parties_vote_share']].idxmax(axis=1).str.replace('_vote_share', '')

# %%
data['incumbent_party'] = data.groupby('constituency_id')['winning_party'].shift(1)

# %%
data['winning_party_changed'] = data['winning_party'] != data['incumbent_party']

# %%
final_data = data[data['year']>2005]
final_data
# Out:
#       year constituency_id               constituency  country  electorate  \
# 1305  2010       E14000530                  ALDERSHOT  England       71465
# 1306  2010       E14000531        ALDRIDGE-BROWNHILLS  England       58909
# 1307  2010       E14000532   ALTRINCHAM AND SALE WEST  England       72208
# 1308  2010       E14000533               AMBER VALLEY  England       70171
# 1309  2010       E14000534    ARUNDEL AND SOUTH DOWNS  England       76835
# ...    ...             ...                        ...      ...         ...
# 3900  2019       E14001059  WYTHENSHAWE AND SALE EAST  England       76313
# 3901  2019       E14001060                     YEOVIL  England       82468
# 3902  2019       W07000041                   YNYS MON    Wales       51925
# 3903  2019       E14001061               YORK CENTRAL  England       74899
# 3904  2019       E14001062                 YORK OUTER  England       74673
#
#       total_votes   tornout  conservative_votes  conservative_vote_share  \
# 1305        45384  0.635052             21203.0                 0.467191
# 1306        38634  0.655825             22913.0                 0.593079
# 1307        49393  0.684038             24176.0                 0.489462
# 1308        45958  0.654943             17746.0                 0.386135
# 1309        55982  0.728600             32333.0                 0.577561
# ...           ...       ...                 ...                      ...
# 3900        44759  0.586519             13459.0                 0.300699
# 3901        59260  0.718582             34588.0                 0.583665
# 3902        36552  0.703938             12959.0                 0.354536
# 3903        49505  0.660957             13767.0                 0.278093
# 3904        55347  0.741192             27324.0                 0.493685
#
#       labour_votes  labour_vote_share  liberal_democrats_votes  \
# 1305        5489.0           0.120946                  15617.0
# 1306        7647.0           0.197934                   6833.0
# 1307       11073.0           0.224182                  12581.0
# 1308       17210.0           0.374472                   6636.0
# 1309        4835.0           0.086367                  15642.0
# ...            ...                ...                      ...
# 3900       23855.0           0.532965                   3111.0
# 3901        3761.0           0.063466                  18407.0
# 3902       10991.0           0.300695                      0.0
# 3903       27312.0           0.551702                   4149.0
# 3904       17339.0           0.313278                   9992.0
#
#       liberal_democrats_vote_share  main_parties_votes  \
# 1305                      0.344108             42309.0
# 1306                      0.176865             37393.0
# 1307                      0.254712             47830.0
# 1308                      0.144393             41592.0
# 1309                      0.279411             52810.0
# ...                            ...                 ...
# 3900                      0.069506             40425.0
# 3901                      0.310614             56756.0
# 3902                      0.000000             23950.0
# 3903                      0.083810             45228.0
# 3904                      0.180534             54655.0
#
#       main_parties_vote_share  other_parties_votes  other_parties_vote_share  \
# 1305                 0.932245               3075.0                  0.067755
# 1306                 0.967878               1241.0                  0.032122
# 1307                 0.968356               1563.0                  0.031644
# 1308                 0.905000               4366.0                  0.095000
# 1309                 0.943339               3172.0                  0.056661
# ...                       ...                  ...                       ...
# 3900                 0.903170               4334.0                  0.096830
# 3901                 0.957746               2504.0                  0.042254
# 3902                 0.655231              12602.0                  0.344769
# 3903                 0.913605               4277.0                  0.086395
# 3904                 0.987497                692.0                  0.012503
#
#      winning_party incumbent_party  winning_party_changed
# 1305  conservative    conservative                  False
# 1306  conservative    conservative                  False
# 1307  conservative    conservative                  False
# 1308  conservative          labour                   True
# 1309  conservative    conservative                  False
# ...            ...             ...                    ...
# 3900        labour          labour                  False
# 3901  conservative    conservative                  False
# 3902  conservative          labour                   True
# 3903        labour          labour                  False
# 3904  conservative    conservative                  False
#
# [2600 rows x 20 columns]

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2600 entries, 1305 to 3904
# Data columns (total 20 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   year                          2600 non-null   int64
#  1   constituency_id               2600 non-null   object
#  2   constituency                  2600 non-null   object
#  3   country                       2600 non-null   object
#  4   electorate                    2600 non-null   int64
#  5   total_votes                   2600 non-null   int64
#  6   tornout                       2600 non-null   float64
#  7   conservative_votes            2600 non-null   float64
#  8   conservative_vote_share       2600 non-null   float64
#  9   labour_votes                  2600 non-null   float64
#  10  labour_vote_share             2600 non-null   float64
#  11  liberal_democrats_votes       2600 non-null   float64
#  12  liberal_democrats_vote_share  2600 non-null   float64
#  13  main_parties_votes            2600 non-null   float64
#  14  main_parties_vote_share       2600 non-null   float64
#  15  other_parties_votes           2600 non-null   float64
#  16  other_parties_vote_share      2600 non-null   float64
#  17  winning_party                 2600 non-null   object
#  18  incumbent_party               2587 non-null   object
#  19  winning_party_changed         2600 non-null   bool
# dtypes: bool(1), float64(11), int64(3), object(5)
# memory usage: 408.8+ KB

# %%
final_data[final_data['incumbent_party'].isnull()]
# Out:
#       year constituency_id                      constituency  country  \
# 1378  2010       E14000603                         BROADLAND  England
# 1398  2010       E14000623                     CENTRAL DEVON  England
# 1404  2010       E14000629                CHELSEA AND FULHAM  England
# 1410  2010       E14000635                        CHIPPENHAM  England
# 1477  2010       E14000702          FILTON AND BRADLEY STOKE  England
# 1542  2010       E14000767            KENILWORTH AND SOUTHAM  England
# 1586  2010       E14000811                       MEON VALLEY  England
# 1589  2010       E14000814                    MID DERBYSHIRE  England
# 1708  2010       E14000933  SOUTH BASILDON AND EAST THURROCK  England
# 1717  2010       E14000942            SOUTH NORTHAMPTONSHIRE  England
# 1736  2010       E14000961            ST AUSTELL AND NEWQUAY  England
# 1820  2010       E14001045                            WITHAM  England
# 1832  2010       E14001057            WYRE AND PRESTON NORTH  England
#
#       electorate  total_votes   tornout  conservative_votes  \
# 1378       72445        52676  0.727117             24338.0
# 1398       71203        53873  0.756611             27737.0
# 1404       66257        39856  0.601536             24093.0
# 1410       72106        52385  0.726500             21500.0
# 1477       69003        48301  0.699984             19686.0
# 1542       64362        48431  0.752478             25945.0
# 1586       70488        51238  0.726904             28818.0
# 1589       66074        47342  0.716500             22877.0
# 1708       71874        44735  0.622409             19624.0
# 1717       82033        59890  0.730072             33081.0
# 1736       75284        47238  0.627464             18877.0
# 1820       66969        46835  0.699353             24448.0
# 1832       70201        51308  0.730873             26877.0
#
#       conservative_vote_share  labour_votes  labour_vote_share  \
# 1378                 0.462032        7287.0           0.138336
# 1398                 0.514859        3715.0           0.068958
# 1404                 0.604501        7371.0           0.184941
# 1410                 0.410423        3620.0           0.069104
# 1477                 0.407569       12772.0           0.264425
# 1542                 0.535711        6949.0           0.143482
# 1586                 0.562434        3266.0           0.063742
# 1589                 0.483228       11585.0           0.244709
# 1708                 0.438672       13852.0           0.309646
# 1717                 0.552363       10380.0           0.173318
# 1736                 0.399615        3386.0           0.071680
# 1820                 0.522003        8656.0           0.184819
# 1832                 0.523836       10932.0           0.213066
#
#       liberal_democrats_votes  liberal_democrats_vote_share  \
# 1378                  17046.0                      0.323601
# 1398                  18507.0                      0.343530
# 1404                   6473.0                      0.162410
# 1410                  23970.0                      0.457574
# 1477                  12197.0                      0.252521
# 1542                  13393.0                      0.276538
# 1586                  16693.0                      0.325793
# 1589                   9711.0                      0.205124
# 1708                   5977.0                      0.133609
# 1717                  12603.0                      0.210436
# 1736                  20189.0                      0.427389
# 1820                   9252.0                      0.197545
# 1832                  11033.0                      0.215035
#
#       main_parties_votes  main_parties_vote_share  other_parties_votes  \
# 1378             48671.0                 0.923969               4005.0
# 1398             49959.0                 0.927348               3914.0
# 1404             37937.0                 0.951852               1919.0
# 1410             49090.0                 0.937100               3295.0
# 1477             44655.0                 0.924515               3646.0
# 1542             46287.0                 0.955731               2144.0
# 1586             48777.0                 0.951969               2461.0
# 1589             44173.0                 0.933062               3169.0
# 1708             39453.0                 0.881927               5282.0
# 1717             56064.0                 0.936116               3826.0
# 1736             42452.0                 0.898683               4786.0
# 1820             42356.0                 0.904366               4479.0
# 1832             48842.0                 0.951937               2466.0
#
#       other_parties_vote_share      winning_party incumbent_party  \
# 1378                  0.076031       conservative             NaN
# 1398                  0.072652       conservative             NaN
# 1404                  0.048148       conservative             NaN
# 1410                  0.062900  liberal_democrats             NaN
# 1477                  0.075485       conservative             NaN
# 1542                  0.044269       conservative             NaN
# 1586                  0.048031       conservative             NaN
# 1589                  0.066938       conservative             NaN
# 1708                  0.118073       conservative             NaN
# 1717                  0.063884       conservative             NaN
# 1736                  0.101317  liberal_democrats             NaN
# 1820                  0.095634       conservative             NaN
# 1832                  0.048063       conservative             NaN
#
#       winning_party_changed
# 1378                   True
# 1398                   True
# 1404                   True
# 1410                   True
# 1477                   True
# 1542                   True
# 1586                   True
# 1589                   True
# 1708                   True
# 1717                   True
# 1736                   True
# 1820                   True
# 1832                   True

# %%
# Save as csv
final_data.to_csv('/Users/andreabrumana/code/willgreen93/UK_election/raw_data/cleaned_elections_data_with_incumbent.csv', index=False)

# %%
client = storage.Client(project="uk-election-406413")
bucket = client.bucket("ukelectiondata")
cleaned_election_results_with_incumbent_blob = bucket.blob("cleaned_elections_data_with_incumbent.csv")
cleaned_election_results_with_incumbent_blob.upload_from_filename("/Users/andreabrumana/code/willgreen93/UK_election/raw_data/cleaned_elections_data_with_incumbent.csv")
