# %%
import pandas as pd

# %%
input_polling_df = pd.read_csv('/Users/andreabrumana/code/willgreen93/UK_election/raw_data/monthly_polling_data.csv')

# %%
input_polling_df
# Out:
#        Year   Month  Conservative  Unnamed: 3  Labour  Unnamed: 5    LD  \
# 0    1983.0      GE          43.5         NaN    28.3         NaN  26.0
# 1    1983.0  Jun-83          43.0         NaN    27.0         NaN  29.0
# 2       NaN  Jul-83          44.8         1.8    28.6         1.6  25.1
# 3       NaN  Aug-83          45.7         0.8    27.4        -1.3  25.5
# 4       NaN  Sep-83          45.5        -0.1    26.7        -0.7  26.3
# ..      ...     ...           ...         ...     ...         ...   ...
# 510     NaN  Aug-24           NaN         NaN     NaN         NaN   NaN
# 511     NaN  Sep-24           NaN         NaN     NaN         NaN   NaN
# 512     NaN  Oct-24           NaN         NaN     NaN         NaN   NaN
# 513     NaN  Nov-24           NaN         NaN     NaN         NaN   NaN
# 514     NaN  Dec-24           NaN         NaN     NaN         NaN   NaN
#
#      Unnamed: 7  UKIP  Unnamed: 9  ...  Green  Unnamed: 16  Unnamed: 17  Lead  \
# 0           NaN   NaN         NaN  ...    NaN          NaN          NaN  15.2
# 1           NaN   NaN         NaN  ...    NaN          NaN          NaN  16.0
# 2          -3.9   NaN         NaN  ...    NaN          NaN          NaN  16.2
# 3           0.4   NaN         NaN  ...    NaN          NaN          NaN  18.3
# 4           0.7   NaN         NaN  ...    NaN          NaN          NaN  18.9
# ..          ...   ...         ...  ...    ...          ...          ...   ...
# 510         NaN   NaN         NaN  ...    NaN          NaN          NaN   NaN
# 511         NaN   NaN         NaN  ...    NaN          NaN          NaN   NaN
# 512         NaN   NaN         NaN  ...    NaN          NaN          NaN   NaN
# 513         NaN   NaN         NaN  ...    NaN          NaN          NaN   NaN
# 514         NaN   NaN         NaN  ...    NaN          NaN          NaN   NaN
#
#      Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  \
# 0            NaN          NaN          NaN          NaN          NaN
# 1            NaN          NaN          NaN          NaN          NaN
# 2            0.2          NaN          NaN          NaN          NaN
# 3            2.1          NaN          NaN          NaN          NaN
# 4            0.6          NaN          NaN          NaN          NaN
# ..           ...          ...          ...          ...          ...
# 510          NaN          NaN          NaN          NaN          NaN
# 511          NaN          NaN          NaN          NaN          NaN
# 512          NaN          NaN          NaN          NaN          NaN
# 513          NaN          NaN          NaN          NaN          NaN
# 514          NaN          NaN          NaN          NaN          NaN
#
#      Unnamed: 24
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 510          NaN
# 511          NaN
# 512          NaN
# 513          NaN
# 514          NaN
#
# [515 rows x 25 columns]

# %%
# We need the polling data BEFORE GENERAL ELECTON!
input_polling_df['Year'] = input_polling_df['Year'].ffill().astype(int)
input_polling_df.head()
# Out:
#    Year   Month  Conservative  Unnamed: 3  Labour  Unnamed: 5    LD  \
# 0  1983      GE          43.5         NaN    28.3         NaN  26.0
# 1  1983  Jun-83          43.0         NaN    27.0         NaN  29.0
# 2  1983  Jul-83          44.8         1.8    28.6         1.6  25.1
# 3  1983  Aug-83          45.7         0.8    27.4        -1.3  25.5
# 4  1983  Sep-83          45.5        -0.1    26.7        -0.7  26.3
#
#    Unnamed: 7  UKIP  Unnamed: 9  ...  Green  Unnamed: 16  Unnamed: 17  Lead  \
# 0         NaN   NaN         NaN  ...    NaN          NaN          NaN  15.2
# 1         NaN   NaN         NaN  ...    NaN          NaN          NaN  16.0
# 2        -3.9   NaN         NaN  ...    NaN          NaN          NaN  16.2
# 3         0.4   NaN         NaN  ...    NaN          NaN          NaN  18.3
# 4         0.7   NaN         NaN  ...    NaN          NaN          NaN  18.9
#
#    Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          0.2          NaN          NaN          NaN          NaN
# 3          2.1          NaN          NaN          NaN          NaN
# 4          0.6          NaN          NaN          NaN          NaN
#
#    Unnamed: 24
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 25 columns]

# %%
pre_GE_rows = input_polling_df.loc[input_polling_df['Month'] == 'GE'].index -1
input_polling_df.loc[pre_GE_rows[1:]] #remove the first one

# Assuming df is your DataFrame
# Get a list of columns that contain the substring 'Unnamed'
unnamed_columns = [col for col in input_polling_df.columns if 'Unnamed' in col]

# Drop the columns with the specified names
input_polling_df = input_polling_df.drop(columns=unnamed_columns)

# %%
input_polling_df = input_polling_df.loc[pre_GE_rows[1:]] #remove the first one
input_polling_df.fillna(0, inplace=True)

# %%
input_polling_df.drop(columns=['Lead'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/andreabrumana/code/willgreen93/UK_election/notebooks/preprocessing/preprocess_polling_data.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/Users/andreabrumana/code/willgreen93/UK_election/notebooks/preprocessing/preprocess_polling_data.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> input_polling_df.drop(columns=['Lead'], inplace=True)
#       <a href='vscode-notebook-cell:/Users/andreabrumana/code/willgreen93/UK_election/notebooks/preprocessing/preprocess_polling_data.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> input_polling_df
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/frame.py:4957, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4809 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4810 def drop(
#    4811     self,
#    (...)
#    4818     errors: str = "raise",
#    4819 ):
#    4820     """
#    4821     Drop specified labels from rows or columns.
#    4822
#    (...)
#    4955             weight  1.0     0.8
#    4956     """
# -> 4957     return super().drop(
#    4958         labels=labels,
#    4959         axis=axis,
#    4960         index=index,
#    4961         columns=columns,
#    4962         level=level,
#    4963         inplace=inplace,
#    4964         errors=errors,
#    4965     )
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/indexes/base.py:6661, in Index.drop(self, labels, errors)
#    6659 if mask.any():
#    6660     if errors != "ignore":
# -> 6661         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6662     indexer = indexer[~mask]
#    6663 return self.delete(indexer)
#
# KeyError: "['Lead'] not found in axis"

# %%
# Identify columns with float dtype (assuming percentage columns are floats)
percentage_columns = input_polling_df.select_dtypes(include='float64').columns

# Divide columns by 100 if they are percentage columns
input_polling_df[percentage_columns] = input_polling_df[percentage_columns] / 100

# %%
input_polling_df['oth_pre_ge'] = 1.0 - input_polling_df['Conservative'] - input_polling_df['Labour'] - input_polling_df['LD']

# %%
input_polling_df
# Out:
#    index  Year  Conservative  Labour     LD  oth_pre_ge
# 0      0  1987         0.428   0.341  0.214       0.017
# 1      1  1992         0.377   0.390  0.196       0.037
# 2      2  1997         0.309   0.493  0.134       0.064
# 3      3  2001         0.314   0.449  0.177       0.060
# 4      4  2005         0.326   0.375  0.228       0.071
# 5      5  2010         0.358   0.281  0.270       0.091
# 6      6  2015         0.336   0.334  0.092       0.238
# 7      7  2017         0.429   0.368  0.077       0.126
# 8      8  2019         0.431   0.332  0.120       0.117

# %%
# Put all the code in a function
def preprocess_polling_data(polling_df):
    cleaned_polling_df = polling_df.copy()
    # fill the missing values for year
    cleaned_polling_df['Year'] = cleaned_polling_df['Year'].ffill().astype(int)
    # Take the rows before the general election
    pre_GE_rows = cleaned_polling_df.loc[cleaned_polling_df['Month'] == 'GE'].index -1
    cleaned_polling_df = cleaned_polling_df.loc[pre_GE_rows[1:]]
    # Identify columns with float dtype (assuming percentage columns are floats)
    percentage_columns = cleaned_polling_df.select_dtypes(include='float64').columns
    # Divide columns by 100 if they are percentage columns
    cleaned_polling_df[percentage_columns] = cleaned_polling_df[percentage_columns] / 100
    # Calculate shate for the other parties
    cleaned_polling_df['oth_pre_ge'] = 1.0 - cleaned_polling_df['Conservative'] - cleaned_polling_df['Labour'] - cleaned_polling_df['LD']
    cleaned_polling_df = cleaned_polling_df[['Year', 'Conservative', 'Labour', 'LD', 'oth_pre_ge']].reset_index(drop=True)
    cleaned_polling_df.columns = ["year", "national_con_pre_ge", "national_lab_pre_ge", "national_lib_pre_ge", "national_oth_pre_ge"]
    return cleaned_polling_df

# %%
preprocess_polling_data = preprocess_polling_data(input_polling_df)
preprocess_polling_data
# Out:
#    year  national_con_pre_ge  national_lab_pre_ge  national_lib_pre_ge  \
# 0  1987                0.428                0.341                0.214
# 1  1992                0.377                0.390                0.196
# 2  1997                0.309                0.493                0.134
# 3  2001                0.314                0.449                0.177
# 4  2005                0.326                0.375                0.228
# 5  2010                0.358                0.281                0.270
# 6  2015                0.336                0.334                0.092
# 7  2017                0.429                0.368                0.077
# 8  2019                0.431                0.332                0.120
#
#    national_oth_pre_ge
# 0                0.017
# 1                0.037
# 2                0.064
# 3                0.060
# 4                0.071
# 5                0.091
# 6                0.238
# 7                0.126
# 8                0.117

# %%
preprocess_polling_data.to_csv('/Users/andreabrumana/code/willgreen93/UK_election/raw_data/preprocessed/preprocessed_polling.csv', index=False)
